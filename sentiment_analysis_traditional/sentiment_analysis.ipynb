# %% [markdown]
# # Sentiment analysis using existing toolkits like Vader and TextBlob

# %%
pip install vaderSentiment
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ------------------------------------ 126.0/126.0 kB 820.6 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->vaderSentiment) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->vaderSentiment) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->vaderSentiment) (2.4.0)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# [notice] A new release of pip available: 22.2.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import csv
import re
import numpy as np
import plotly.express as px
from plotly.offline import init_notebook_mode
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from pre import clean_text, remove_stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("../data/threads_data.csv")
df
# Out:
#            tweet_id_str                       date_time  \
# 0   1907092398431510754  Tue Apr 01 15:27:14 +0000 2025
# 1   1903892256891052215  Sun Mar 23 19:31:01 +0000 2025
# 2   1907089741432180745  Tue Apr 01 15:16:41 +0000 2025
# 3   1907337838401646625  Wed Apr 02 07:42:31 +0000 2025
# 4   1858545925326856373  Mon Nov 18 16:20:53 +0000 2024
# ..                  ...                             ...
# 90   939886467089760257  Sun Dec 10 15:56:10 +0000 2017
# 91  1173619244124258304  Mon Sep 16 15:26:47 +0000 2019
# 92  1908802423881080920  Sun Apr 06 08:42:16 +0000 2025
# 93  1909218199293338054  Mon Apr 07 12:14:24 +0000 2025
# 94  1910190994097631636  Thu Apr 10 04:39:57 +0000 2025
#
#                          location  \
# 0                  Fascist Regime
# 1                             NaN
# 2                           K'tka
# 3                           K'tka
# 4                           India
# ..                            ...
# 90  coolandfunnytshirts@gmail.com
# 91               New Delhi, India
# 92                            NaN
# 93               wherever you are
# 94                            NaN
#
#                                            tweet_text  media_urls
# 0   must watch kunal kamra , another stand comedia...         NaN
# 1   modi bhakts cell destroyed top class humour st...         NaN
# 2   devesh dixit , stand comedian came another nig...         NaN
# 3   devesh dixit , stand comedian taking bjp clean...         NaN
# 4   samay raina , best stand comedian india right ...         NaN
# ..                                                ...         ...
# 90  well deserved. practically one congress worth ...         NaN
# 91  start speech ravish kumar , moving nidhi razda...         NaN
# 92  gadmad ho gya sab .. one leader modiji one jok...         NaN
# 93  stand comedian video likely nishant tanwar. ro...         NaN
# 94  politics imtiazsiddique netan enjoy ... comedy...         NaN
#
# [95 rows x 5 columns]

# %%
df['tweet_text']
# Out:
# 0     must watch kunal kamra , another stand comedia...
# 1     modi bhakts cell destroyed top class humour st...
# 2     devesh dixit , stand comedian came another nig...
# 3     devesh dixit , stand comedian taking bjp clean...
# 4     samay raina , best stand comedian india right ...
#                             ...
# 90    well deserved. practically one congress worth ...
# 91    start speech ravish kumar , moving nidhi razda...
# 92    gadmad ho gya sab .. one leader modiji one jok...
# 93    stand comedian video likely nishant tanwar. ro...
# 94    politics imtiazsiddique netan enjoy ... comedy...
# Name: tweet_text, Length: 95, dtype: object

# %% [markdown]
# <hr>

# %% [markdown]
# ## 1. Sentiment Analysis with TextBlob

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
your_text = 'I like this comedy'
getPolarity(your_text), getSubjectivity(your_text)
# Out:
# (0.0, 0.0)

# %% [markdown]
# We now have subjectivity and polarity scores for each of our tweets, which we add to our dataframe.

# %%
df['tweet_text'] = df['tweet_text'].fillna('')

def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

df['subjectivity'] = df['tweet_text'].apply(getSubjectivity)
df['polarity'] = df['tweet_text'].apply(getPolarity)

df
# Out:
#            tweet_id_str                       date_time  \
# 0   1907092398431510754  Tue Apr 01 15:27:14 +0000 2025
# 1   1903892256891052215  Sun Mar 23 19:31:01 +0000 2025
# 2   1907089741432180745  Tue Apr 01 15:16:41 +0000 2025
# 3   1907337838401646625  Wed Apr 02 07:42:31 +0000 2025
# 4   1858545925326856373  Mon Nov 18 16:20:53 +0000 2024
# ..                  ...                             ...
# 90   939886467089760257  Sun Dec 10 15:56:10 +0000 2017
# 91  1173619244124258304  Mon Sep 16 15:26:47 +0000 2019
# 92  1908802423881080920  Sun Apr 06 08:42:16 +0000 2025
# 93  1909218199293338054  Mon Apr 07 12:14:24 +0000 2025
# 94  1910190994097631636  Thu Apr 10 04:39:57 +0000 2025
#
#                          location  \
# 0                  Fascist Regime
# 1                             NaN
# 2                           K'tka
# 3                           K'tka
# 4                           India
# ..                            ...
# 90  coolandfunnytshirts@gmail.com
# 91               New Delhi, India
# 92                            NaN
# 93               wherever you are
# 94                            NaN
#
#                                            tweet_text  media_urls  \
# 0   must watch kunal kamra , another stand comedia...         NaN
# 1   modi bhakts cell destroyed top class humour st...         NaN
# 2   devesh dixit , stand comedian came another nig...         NaN
# 3   devesh dixit , stand comedian taking bjp clean...         NaN
# 4   samay raina , best stand comedian india right ...         NaN
# ..                                                ...         ...
# 90  well deserved. practically one congress worth ...         NaN
# 91  start speech ravish kumar , moving nidhi razda...         NaN
# 92  gadmad ho gya sab .. one leader modiji one jok...         NaN
# 93  stand comedian video likely nishant tanwar. ro...         NaN
# 94  politics imtiazsiddique netan enjoy ... comedy...         NaN
#
#     subjectivity  polarity
# 0       0.750000 -0.587500
# 1       0.415179  0.196429
# 2       0.500000 -0.300000
# 3       0.500000 -0.300000
# 4       0.417857  0.642857
# ..           ...       ...
# 90      0.550000  0.316667
# 91      0.000000  0.000000
# 92      1.000000 -0.900000
# 93      0.705000  0.175000
# 94      0.500000  0.400000
#
# [95 rows x 7 columns]

# %% [markdown]
# Creating a function to add a sentiment label to each tweet, based on it's polarity score.

# %%
def get_sentiment_label(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
# Apply the get_sentiment_label function to the polarity column
# and add the sentiment results as a new column in our dataframe

df['TBsentiment'] = df['polarity'].apply(get_sentiment_label)
df
# Out:
#            tweet_id_str                       date_time  \
# 0   1907092398431510754  Tue Apr 01 15:27:14 +0000 2025
# 1   1903892256891052215  Sun Mar 23 19:31:01 +0000 2025
# 2   1907089741432180745  Tue Apr 01 15:16:41 +0000 2025
# 3   1907337838401646625  Wed Apr 02 07:42:31 +0000 2025
# 4   1858545925326856373  Mon Nov 18 16:20:53 +0000 2024
# ..                  ...                             ...
# 90   939886467089760257  Sun Dec 10 15:56:10 +0000 2017
# 91  1173619244124258304  Mon Sep 16 15:26:47 +0000 2019
# 92  1908802423881080920  Sun Apr 06 08:42:16 +0000 2025
# 93  1909218199293338054  Mon Apr 07 12:14:24 +0000 2025
# 94  1910190994097631636  Thu Apr 10 04:39:57 +0000 2025
#
#                          location  \
# 0                  Fascist Regime
# 1                             NaN
# 2                           K'tka
# 3                           K'tka
# 4                           India
# ..                            ...
# 90  coolandfunnytshirts@gmail.com
# 91               New Delhi, India
# 92                            NaN
# 93               wherever you are
# 94                            NaN
#
#                                            tweet_text  media_urls  \
# 0   must watch kunal kamra , another stand comedia...         NaN
# 1   modi bhakts cell destroyed top class humour st...         NaN
# 2   devesh dixit , stand comedian came another nig...         NaN
# 3   devesh dixit , stand comedian taking bjp clean...         NaN
# 4   samay raina , best stand comedian india right ...         NaN
# ..                                                ...         ...
# 90  well deserved. practically one congress worth ...         NaN
# 91  start speech ravish kumar , moving nidhi razda...         NaN
# 92  gadmad ho gya sab .. one leader modiji one jok...         NaN
# 93  stand comedian video likely nishant tanwar. ro...         NaN
# 94  politics imtiazsiddique netan enjoy ... comedy...         NaN
#
#     subjectivity  polarity TBsentiment
# 0       0.750000 -0.587500    Negative
# 1       0.415179  0.196429    Positive
# 2       0.500000 -0.300000    Negative
# 3       0.500000 -0.300000    Negative
# 4       0.417857  0.642857    Positive
# ..           ...       ...         ...
# 90      0.550000  0.316667    Positive
# 91      0.000000  0.000000     Neutral
# 92      1.000000 -0.900000    Negative
# 93      0.705000  0.175000    Positive
# 94      0.500000  0.400000    Positive
#
# [95 rows x 8 columns]

# %% [markdown]
# We can have a quick look at the sentiment distribution of the tweets as follows:

# %%
df['TBsentiment'].value_counts()
# Out:
# TBsentiment
# Positive    65
# Neutral     18
# Negative    12
# Name: count, dtype: int64

# %%
# Filter and print the negative sentiment tweets
negative_tweets = df[df['TBsentiment'] == 'Negative']
print("\nNegative Sentiment Tweets:")
print(negative_tweets[['tweet_text', 'polarity']])
# Out:
# Negative Sentiment Tweets:
#                                            tweet_text  polarity
# 0   must watch kunal kamra , another stand comedia... -0.587500
# 2   devesh dixit , stand comedian came another nig... -0.300000
# 3   devesh dixit , stand comedian taking bjp clean... -0.300000
# 26  new stand bit talk little modiji , jaitley sah... -0.025568
# 28  comedians cancel stand shows due public outrag... -0.062500
# 57  look shakeel siddiqi , umar sharief , moin akh... -0.076923
# 68  remember laughing insanely stand ups raju sriv... -0.417143
# 72  everytime leftist comedian gets news outrageou... -0.350000
# 79  wonder rohan joshi ' aib failed ! raju shrivas... -0.398810
# 85  since dis qualified mp , must take standup com... -0.010606
# 86  joking becomes crime world ' largest democracy... -0.050000
# 92  gadmad ho gya sab .. one leader modiji one jok... -0.900000

# %%
sorted_df = df.sort_values(by=['polarity'], ascending=False)

# %% [markdown]
# Top 15 most _positive_ tweets, which are now the first 15 tweets in the new dataframe.

# %%
for i, tweet in enumerate(sorted_df.head(15)['tweet_text']):
    print(i+1, tweet, '\n')
# Out:
# 1 arnav goswami exposes us democrats rahul gandhi. arnav monologues best.
#
# 2 rahul gandhi currently best stand comedian
#
# 3 kunal kamra munawar faruqi best stand comics came region. pakistani standup comics dont even balls tweet jokes topics let alone perform infront audience .
#
# 4 abhishek upmanyu best indian stand comedian. content , delivery , gestures , structure show. everything perfect .
#
# 5 manik mahna upmanyu best indian stand comedians cap fr fr
#
# 6 best joke stand comedian stands up. everytime congressi walks .
#
# 7 kejriwal replaced rahul gandhi best comedian india
#
# 8 raju srivastava , best ever stand comedian ever known. versatile personality always remembered humour amp gentlemanship.
#
# 9 guys brilliant #politicalcomedy
#
# 10 must read article stand comedian anti india propagandist ? brilliant article
#
# 11 india produced great humourists satirists. stand , would vote jaspal bhatti. choices ?
#
# 12 #kapilsharma overrated comedian propelled salman ' khan pr agencies. best stand comedian raju srivastava truly original
#
# 13 samay raina , best stand comedian india right now.
#
# 14 namaste ! yahan 2025 ke top 10 indian stand comedians ki list hai 1. anubhav singh bassi , 2. abhishek upmanyu , 3. zakir khan , 4. vir das , 5. rahul dua , 6. kapil sharma , 7. abish mathew , 8. aditi mittal , 9. rahul subramanian , 10. atul kataria. ye list online popularity , youtube subscribers , aur netflix specials pe based hai. pasand apki ho sakti hai alag !
#
# 15 best comedian year award goes ramesh jairam ramesh already crossed 272 amp win 350 seats. india govt next week

# %% [markdown]
# Top 15 most _negative_ tweets, which are now the last 15 tweets in the new dataframe.

# %%
for i, tweet in enumerate(sorted_df.tail(15)['tweet_text']):
    print(i+1, tweet, '\n')
# Out:
# 1 tallest shortest height jokers indian politics exposes level time amp leaves stone unturned entertain public
#
# 2 days indian stand comedy reduced taking political potshot , ridiculing prime minister , maligning hindu religion amp festivals , glorifying separatists. comedy left .
#
# 3 unfair ! many stand comedians news channels. remember #aajtak sweta singh nanochip r2000 note ? navika kumar raga movies ? gaurav sawant calf runs meet greet yogi ? bhupendra choube sunny leone ? arnab anytime !
#
# 4 since dis qualified mp , must take standup comedy new profession serious note. speeches far proved massive hidden talent man .. comedy .. comedy must real passion ..
#
# 5 new stand bit talk little modiji , jaitley sahab , arnab goswami others. watch , rt like it. link
#
# 6 joking becomes crime world ' largest democracy , wire ' discusses comedian sanjay rajoura , parvezhassan , political comedy becoming dangerous india.
#
# 7 comedians cancel stand shows due public outrage. 1. munawar faroqqi 2. kunal kamra 3. narendra modi
#
# 8 look shakeel siddiqi , umar sharief , moin akhtar epitome comedy , loose talk , barkat uzmi , khalid butt
#
# 9 devesh dixit , stand comedian came another nightmare bjp rw ecosystem demonetization done common man , done buy mlas watch amp spread gem.
#
# 10 devesh dixit , stand comedian taking bjp cleaners demonetization done common man buy mlas vandalize venue ?
#
# 11 everytime leftist comedian gets news outrageous anti hindu anti india stuff , remember gangavathi pranesh. given 3500 public stand comedy shows. travelled 11 nations. household name karnataka. never news demeaning country religion !
#
# 12 wonder rohan joshi ' aib failed ! raju shrivastav , sunil pal , ehsan qureshi pioneers stand comedy amp mind never uttered single false word gain popularity matter humiliated audience name crowd work gain popularity !
#
# 13 remember laughing insanely stand ups raju srivastava , sunil pal others. pure comedy without tinch propoganda. wonder morons replaced actual comedians , went wrong ?
#
# 14 must watch kunal kamra , another stand comedian brutally trolled bjp demonetization done common people , buy mlas another burn l moment bjp cell amp rw ecosystem
#
# 15 gadmad ho gya sab .. one leader modiji one joker opposition comedian raul retard ghandoo

# %% [markdown]
# Now let's visualise distribution of the polarity and subjectivity assignments from TextBlob. To do this, we will make use of interactive plots from [Plotly](https://plotly.com/python/).
#
# Interactive Plotly plots make use of JavaScript behind the scenes. To connect our Jupyter notebook with JavaScript, we need to execute the following line of code:

# %%
# ___Cell no. 12___

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %% [markdown]
# Below, we use [Plotly Express](https://plotly.com/python/plotly-express/) to create a simple scatter plot of the polarity and subjectivity data. As this is an interactive plot, you will be able to hover your mouse over a point to view it's properties.
#
# Note how plotly express automatically labels our axes for us according to our dataframe column names.

# %%
from plotly.offline import plot

# ___Cell no. 13___

# Use plotly offline mode to render the plot
fig = px.scatter(df, x="polarity", y="subjectivity", hover_data=['tweet_text'],
                 title="TextBlob Sentiment Analysis")

# Plot offline
plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# <hr>

# %% [markdown]
# ## 2. Sentiment Analysis with VADER

# %%
analyser = SentimentIntensityAnalyzer()

# %%
# ___Cell no. 15___

your_text = 'i like this movie'
analyser.polarity_scores(your_text)
# Out:
# {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.3612}

# %% [markdown]
# Let us now use VADER to retrieve the compound sentiment score for all tweets and add this information to our original (unsorted) dataframe.

# %%
#Create a function to get the polarity

def get_vaderCompoundPolarity(text):
    return analyser.polarity_scores(text)['compound']
    
df['vader_compound'] = df['tweet_text'].apply(get_vaderCompoundPolarity)
df
# Out:
#            tweet_id_str                       date_time  \
# 0   1907092398431510754  Tue Apr 01 15:27:14 +0000 2025
# 1   1903892256891052215  Sun Mar 23 19:31:01 +0000 2025
# 2   1907089741432180745  Tue Apr 01 15:16:41 +0000 2025
# 3   1907337838401646625  Wed Apr 02 07:42:31 +0000 2025
# 4   1858545925326856373  Mon Nov 18 16:20:53 +0000 2024
# ..                  ...                             ...
# 90   939886467089760257  Sun Dec 10 15:56:10 +0000 2017
# 91  1173619244124258304  Mon Sep 16 15:26:47 +0000 2019
# 92  1908802423881080920  Sun Apr 06 08:42:16 +0000 2025
# 93  1909218199293338054  Mon Apr 07 12:14:24 +0000 2025
# 94  1910190994097631636  Thu Apr 10 04:39:57 +0000 2025
#
#                          location  \
# 0                  Fascist Regime
# 1                             NaN
# 2                           K'tka
# 3                           K'tka
# 4                           India
# ..                            ...
# 90  coolandfunnytshirts@gmail.com
# 91               New Delhi, India
# 92                            NaN
# 93               wherever you are
# 94                            NaN
#
#                                            tweet_text  media_urls  \
# 0   must watch kunal kamra , another stand comedia...         NaN
# 1   modi bhakts cell destroyed top class humour st...         NaN
# 2   devesh dixit , stand comedian came another nig...         NaN
# 3   devesh dixit , stand comedian taking bjp clean...         NaN
# 4   samay raina , best stand comedian india right ...         NaN
# ..                                                ...         ...
# 90  well deserved. practically one congress worth ...         NaN
# 91  start speech ravish kumar , moving nidhi razda...         NaN
# 92  gadmad ho gya sab .. one leader modiji one jok...         NaN
# 93  stand comedian video likely nishant tanwar. ro...         NaN
# 94  politics imtiazsiddique netan enjoy ... comedy...         NaN
#
#     subjectivity  polarity TBsentiment  vader_compound
# 0       0.750000 -0.587500    Negative          0.1531
# 1       0.415179  0.196429    Positive          0.1027
# 2       0.500000 -0.300000    Negative          0.3818
# 3       0.500000 -0.300000    Negative          0.3818
# 4       0.417857  0.642857    Positive          0.7783
# ..           ...       ...         ...             ...
# 90      0.550000  0.316667    Positive          0.7650
# 91      0.000000  0.000000     Neutral          0.0000
# 92      1.000000 -0.900000    Negative         -0.0772
# 93      0.705000  0.175000    Positive          0.9442
# 94      0.500000  0.400000    Positive          0.4588
#
# [95 rows x 9 columns]

# %% [markdown]
# Let us once again apply the 'get_sentiment_label' function to assign the VADER sentiment of each tweet given the compound score.

# %%
# Apply the get_sentiment_label function to the VADER compound score
# and add the VADER sentiment results as a new column in our dataframe

df['VADERsentiment'] = df['vader_compound'].apply(get_sentiment_label)
df
# Out:
#            tweet_id_str                       date_time  \
# 0   1907092398431510754  Tue Apr 01 15:27:14 +0000 2025
# 1   1903892256891052215  Sun Mar 23 19:31:01 +0000 2025
# 2   1907089741432180745  Tue Apr 01 15:16:41 +0000 2025
# 3   1907337838401646625  Wed Apr 02 07:42:31 +0000 2025
# 4   1858545925326856373  Mon Nov 18 16:20:53 +0000 2024
# ..                  ...                             ...
# 90   939886467089760257  Sun Dec 10 15:56:10 +0000 2017
# 91  1173619244124258304  Mon Sep 16 15:26:47 +0000 2019
# 92  1908802423881080920  Sun Apr 06 08:42:16 +0000 2025
# 93  1909218199293338054  Mon Apr 07 12:14:24 +0000 2025
# 94  1910190994097631636  Thu Apr 10 04:39:57 +0000 2025
#
#                          location  \
# 0                  Fascist Regime
# 1                             NaN
# 2                           K'tka
# 3                           K'tka
# 4                           India
# ..                            ...
# 90  coolandfunnytshirts@gmail.com
# 91               New Delhi, India
# 92                            NaN
# 93               wherever you are
# 94                            NaN
#
#                                            tweet_text  media_urls  \
# 0   must watch kunal kamra , another stand comedia...         NaN
# 1   modi bhakts cell destroyed top class humour st...         NaN
# 2   devesh dixit , stand comedian came another nig...         NaN
# 3   devesh dixit , stand comedian taking bjp clean...         NaN
# 4   samay raina , best stand comedian india right ...         NaN
# ..                                                ...         ...
# 90  well deserved. practically one congress worth ...         NaN
# 91  start speech ravish kumar , moving nidhi razda...         NaN
# 92  gadmad ho gya sab .. one leader modiji one jok...         NaN
# 93  stand comedian video likely nishant tanwar. ro...         NaN
# 94  politics imtiazsiddique netan enjoy ... comedy...         NaN
#
#     subjectivity  polarity TBsentiment  vader_compound VADERsentiment
# 0       0.750000 -0.587500    Negative          0.1531       Positive
# 1       0.415179  0.196429    Positive          0.1027       Positive
# 2       0.500000 -0.300000    Negative          0.3818       Positive
# 3       0.500000 -0.300000    Negative          0.3818       Positive
# 4       0.417857  0.642857    Positive          0.7783       Positive
# ..           ...       ...         ...             ...            ...
# 90      0.550000  0.316667    Positive          0.7650       Positive
# 91      0.000000  0.000000     Neutral          0.0000        Neutral
# 92      1.000000 -0.900000    Negative         -0.0772       Negative
# 93      0.705000  0.175000    Positive          0.9442       Positive
# 94      0.500000  0.400000    Positive          0.4588       Positive
#
# [95 rows x 10 columns]

# %% [markdown]
# let's have a look at what VADER has classified as the 15 most postive and negative tweets by using the same method shown in the TextBlob example.

# %%
sorted_df2 = df.sort_values(by=['vader_compound'], ascending=False)

# %%
for i, tweet in enumerate(sorted_df2.head(15)['tweet_text']):
    print(i+1, tweet, '\n')
# Out:
# 1 gurpatwant singh pannu , upcoming standup comedian republic khalistan ! disclaimer purely entertainment purposes. get ready laughs ! seems gurpatwant singh pannu overtaken neetu shatran wala world standup comedy ! competing kapil sharma though sadly , visit india. perhaps sony entertainment television netflix brace threats near future ! secret hideout , pannu recently released two hilarious video clips. one , offers 25k information whereabouts public appearances indian ambassador shri vinay kwatra russian high commissioner canada. real joke diplomats schedules events already publicly announced ! well respected figures , educated , responsible. seems pannu looking way stay spotlight. second statement , pannu hilariously claimed russia supplying chemical grenades india used farmers agitation , ones used ukraine war. threatened india chemical minister , according , amit shah. unfortunately , actual chemical minister jp nadda , shah. looks like pannu scriptwriter needs fired mix ! think pannu spends much time twitter , checking pictures leaders. , let share findings recent trip punjab. old farmer shambu border told pannu ever sets foot punjab , love pull ponytail spreading false propaganda attempts hijack farmers agitation. visited pannu village , khankot amritsar district elderly locals shared supposedly lost mental balance years ago inhaling carbon monoxide retrieving something motor well. , began claiming would one day become president uganda buy kenya ! villagers tried desi remedies , nothing worked , eventually , taken chandigarh treatment. chandigarh , one pannu classmates told take seriously , struggling mental health issues years. according friends , people diaspora think brave , reality , never even raised stick dog. record , disagree friends one harm animals ! back california , respectable sikh gentleman san jose shared pannu seek mental health treatment. baseless laughable statements ny safe house damaging reputation sikhs globally. locally , even heard pannu daily comedic rants becoming major setback khalistan cause ! please check short video clip attached. record longer one keep laughing behind curtain ! lastly , offer sincere apologies neetu shatran wala case comments hurt feelings. sat sri akal sukhi chahal fair fearless voice truth sikh activist champion united united progressive peaceful location san jose , california , usa follow twitter
#
# 2 problem political comedy people ' laughing jokes , clapping agree you. rajneesh kapoor says ' working roast amit shah would like test bjp supporters. ' laugh , jokes working ' . #mediarumble
#
# 3 stand comedian video likely nishant tanwar. routine comedy club , wearing orange shirt , humorously critiques casteism india unique spider man reference. known hindi comedy specials like gaadi tera bhai chalayega , tanwar style matches content bhai sahab nickname post. comedians like anubhav singh bassi also tackle similar themes , specific lines setting point tanwar .
#
# 4 best standup comedy people appealing mamta banerjee , people , save freedom speech , fight fascism , uphold democracy. musical accompaniment standup comedy world smallest violin playing confessed unemployable
#
# 5 tuesday humour watch ! great joy elections meet range people. last night varanasi , met stand comedian whose nomination papers rejected highly specious grounds. asked shyam mimic major netas narendra modi rahul gandhi others would react breaking news nomination denial. followed bit fun ! #electionsonmyplate watch
#
# 6 best comedian year award goes ramesh jairam ramesh already crossed 272 amp win 350 seats. india govt next week
#
# 7 best entertaining political comedy special year far ... , dropping truth bombs style ... watch gets removed ! #nayabharat
#
# 8 #kapilsharma overrated comedian propelled salman ' khan pr agencies. best stand comedian raju srivastava truly original
#
# 9 comedians apologise state govt maharashtra got physical slap workers. champions freedom speech anurag kashyap swara bhaskar rajdeep barkha sagarika rana ayyub javed akhtar taken fevicol mouth keep quiet .
#
# 10 lol ! ! ' stop laughing #arnabgoswami best comedian right india ! ! bark behind #salmankhan ' , post.
#
# 11 massive respect indian standup comics like kunal kamra daniel fernandez brave calling spade spade modi govt. meanwhile clowns like shehzad ghias akbar chaudhary types still cracking gutka mawa jokes
#
# 12 big news muslim comedian zakir khan praised clean comedy. ranveer allahabadia slammed senseless demeaning comedy. ranveer allahabadia , samay raina , apurva mukhija crossed line india ' got latent show. several cases registered .
#
# 13 indian stand comedian funny relevant even today p l deshpande.the smallest description characters one amazing art had. today click bait bigots , cashing free publicity would get insulting hindu icons #justsaying
#
# 14 please go watch ' aazaadi tour . one bold comedy show recent times , watched ahmedabad , loved every bit it. touched every burning issue country , media scared talk , made ppl laugh .
#
# 15 since dis qualified mp , must take standup comedy new profession serious note. speeches far proved massive hidden talent man .. comedy .. comedy must real passion ..

# %%
#Print out the text from the last 15 tweets in the sorted dataframe

for i, tweet in enumerate(sorted_df2.tail(15)['tweet_text']):
    print(i+1, tweet, '\n')
# Out:
# 1 tallest shortest height jokers indian politics exposes level time amp leaves stone unturned entertain public
#
# 2 must watch kunal kamra , another stand comedian brutally trolled bjp demonetization done common people , buy mlas another burn l moment bjp cell amp rw ecosystem
#
# 3 modi bhakts cell destroyed top class humour stand kunal kamra shaken entire bjp , filing firs left right this. watch deleted
#
# 4 look shakeel siddiqi , umar sharief , moin akhtar epitome comedy , loose talk , barkat uzmi , khalid butt
#
# 5 start speech ravish kumar , moving nidhi razdan , rajdeep sardesai , sagarika ghose , course barkha dutt , srinivasan jain , faye souza , karan thapar , abhisar sharma , arfa khanum , shekhar gupta , prannoy roy amp tell students anything idolize
#
# 6 india #standupcomedy ecosystem used entirely dominated wokes qaumreds. slowly , h right breaking doors bastion too.
#
# 7 #standup #kunalkamara #kunalkamracontroversy #politicaljoke #politicalsatire
#
# 8 gadmad ho gya sab .. one leader modiji one joker opposition comedian raul retard ghandoo
#
# 9 #trendingtonight bigger problem. living country one ' crack joke politicians political satirist akash banerjee
#
# 10 joking becomes crime world ' largest democracy , wire ' discusses comedian sanjay rajoura , parvezhassan , political comedy becoming dangerous india.
#
# 11 ye lag raha hai script aditya thackeray ne likh ke diya hai .. full standup politics ..
#
# 12 stand comic ' dissection india ' obsession fairness skin deep.
#
# 13 soon stand comic able perform india. right munawar farooqi others stand combine , whole fraternity trouble lumpen elements decide
#
# 14 everytime leftist comedian gets news outrageous anti hindu anti india stuff , remember gangavathi pranesh. given 3500 public stand comedy shows. travelled 11 nations. household name karnataka. never news demeaning country religion !
#
# 15 comedians cancel stand shows due public outrage. 1. munawar faroqqi 2. kunal kamra 3. narendra modi

# %% [markdown]
# Compare the sentiment assignments of TextBlob and VADER by plotting another Plotly interactive scatter plot.

# %%
import plotly.express as px
from plotly.offline import plot

fig = px.scatter(df, x="polarity", y="vader_compound", hover_data=['tweet_text'],
                 title="TextBlob vs VADER")

plot(fig, filename='textblob_vs_vader.html')
# Out:
# 'textblob_vs_vader.html'
